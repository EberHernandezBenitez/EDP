# %% [markdown]
# <a href="https://colab.research.google.com/github/EberHernandezBenitez/EDP/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp

# Variables simbólicas
x, w = sp.symbols('x w', real=True)

# a) Definición de la función pulso unitario
f = sp.Piecewise((1, (x >= -1) & (x <= 1)), (0, True))

# b) Representación como integral de Fourier
Fw = sp.integrate(f * sp.exp(-1j * w * x), (x, -sp.oo, sp.oo))  # Transformada de Fourier
F_inv = sp.integrate(Fw * sp.exp(1j * w * x) / (2 * sp.pi), (w, -sp.oo, sp.oo))  # Inversa formal

# Función para evaluación numérica
f_numeric = sp.lambdify(x, f, 'numpy')

# Graficar función original
x_vals = np.linspace(-4, 4, 1000)
f_vals = f_numeric(x_vals)

plt.figure(figsize=(10, 6))
plt.plot(x_vals, f_vals, label='f(x) original')
plt.title('a) Función pulso unitario')
plt.grid()
plt.legend()
plt.show()

# b) Reconstrucción desde la transformada de Fourier
# F(w) = ∫_{-1}^{1} e^{-iwx} dx = 2 sin(w)/w
Fw_simple = sp.integrate(sp.exp(-1j * w * x), (x, -1, 1))
F_inv_sym = sp.integrate(Fw_simple * sp.exp(1j * w * x) / (2 * sp.pi), (w, -sp.oo, sp.oo), conds='none')

# Aproximación numérica de la integral inversa
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp

# Variables simbólicas
x, w = sp.symbols('x w', real=True)

# a) Definición de la función pulso unitario
f = sp.Piecewise((1, (x >= -1) & (x <= 1)), (0, True))

# b) Representación como integral de Fourier
Fw = sp.integrate(f * sp.exp(-1j * w * x), (x, -sp.oo, sp.oo))  # Transformada de Fourier
F_inv = sp.integrate(Fw * sp.exp(1j * w * x) / (2 * sp.pi), (w, -sp.oo, sp.oo))  # Inversa formal

# Función para evaluación numérica
f_numeric = sp.lambdify(x, f, 'numpy')

# Graficar función original
x_vals = np.linspace(-4, 4, 1000)
f_vals = f_numeric(x_vals)

plt.figure(figsize=(10, 6))
plt.plot(x_vals, f_vals, label='f(x) original')
plt.title('a) Función pulso unitario')
plt.grid()
plt.legend()
plt.show()

# b) Reconstrucción desde la transformada de Fourier
# F(w) = ∫_{-1}^{1} e^{-iwx} dx = 2 sin(w)/w
Fw_simple = sp.integrate(sp.exp(-1j * w * x), (x, -1, 1))
F_inv_sym = sp.integrate(Fw_simple * sp.exp(1j * w * x) / (2 * sp.pi), (w, -sp.oo, sp.oo), conds='none')

# Aproximación numérica de la integral inversa
def fourier_approx(x_vals, a_val):
    w_vals = sp.Symbol('w')
    integrand = 2 * sp.sin(w_vals)/w_vals * sp.exp(1j * w_vals * a_val) / (2 * sp.pi)
    # We would need a numerical integration function here.
    # For demonstration, let's just use the symbolic inverse if possible or a simplified approach.
    # SymPy's integrate can handle some definite integrals.

    # Let's try to evaluate the symbolic result numerically for a few points
    f_inv_numeric = sp.lambdify(x, F_inv_sym, 'numpy')
    return f_inv_numeric(x_vals)

# Choose a value for 'a' for the approximation point(s) if needed, or just evaluate on a range
# For direct comparison, let's evaluate the symbolic inverse result numerically on the same range
f_inv_numeric_vals = fourier_approx(x_vals, x_vals) # This line is conceptual, sp.lambdify handles the x range

plt.figure(figsize=(10, 6))
plt.plot(x_vals, f_vals, label='f(x) original')
plt.plot(x_vals, f_inv_numeric_vals.real, label='Reconstrucción (parte real)')
plt.plot(x_vals, f_inv_numeric_vals.imag, label='Reconstrucción (parte imaginaria)') # Should be close to 0
plt.title('b) Reconstrucción de la función pulso usando Transformada de Fourier')
plt.grid()
plt.legend()
plt.show()

# c) Interpretación del resultado

print("\nInterpretación del resultado:")
print("La gráfica muestra la función pulso unitario original y la reconstrucción obtenida al aplicar la transformada inversa de Fourier.")
print("Idealmente, la reconstrucción debería coincidir perfectamente con la función original.")
print("Sin embargo, la representación mediante una integral (Transformada de Fourier) implica que la reconstrucción puede mostrar:")
print("- Fenómeno de Gibbs en las discontinuidades (oscilaciones alrededor de los bordes del pulso).")
print("- La parte imaginaria de la reconstrucción debería ser muy cercana a cero para una función real como el pulso.")
print("La precisión de la reconstrucción numérica depende de la técnica de integración numérica utilizada.")
print("La expresión simbólica de la inversa de Fourier (F_inv_sym) obtenida por SymPy representa la reconstrucción teórica.")
print("La evaluación numérica de esta expresión simbólica debería aproximarse a la función original, mostrando el fenómeno de Gibbs en la práctica.")
# Out:
# ---------------------------------------------------------------------------
# PrintMethodNotImplementedError            Traceback (most recent call last)
# <ipython-input-2-1734524427> in <cell line: 0>()
#      80 # Choose a value for 'a' for the approximation point(s) if needed, or just evaluate on a range
#      81 # For direct comparison, let's evaluate the symbolic inverse result numerically on the same range
# ---> 82 f_inv_numeric_vals = fourier_approx(x_vals, x_vals) # This line is conceptual, sp.lambdify handles the x range
#      83
#      84 plt.figure(figsize=(10, 6))
#
# <ipython-input-2-1734524427> in fourier_approx(x_vals, a_val)
#      75
#      76     # Let's try to evaluate the symbolic result numerically for a few points
# ---> 77     f_inv_numeric = sp.lambdify(x, F_inv_sym, 'numpy')
#      78     return f_inv_numeric(x_vals)
#      79
#
# ...
